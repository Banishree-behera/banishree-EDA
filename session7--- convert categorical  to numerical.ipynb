# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)

# %%
#in machine learning it is vry important to convert categorical data to 
# machine learning models develop by maths
#machine learning takes the the input in the form of numbers only
#to convert the we have some encoding techniques
#level encoder
  #map 
    #np.where
    #using sklearn package: label encoder
#one hot encoder
#using pandas package :pd.get_dummies

# %% [markdown]
# $map$
# -before applying map method first get the unique labels of the column
#
# -for example case_status is a categorical column
#
# -it has two unique labels are there
#
#    denied
#
#     certified

# %%
visa_df['case_status'].unique()

# %%
d={'certified':0,'denied':1}
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df

# %%
visa_df['continent'].unique()

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)

d={}
labels=visa_df['continent'].unique()
for i in range(len(labels)):
    d[labels[i]]=i

visa_df['continent']=visa_df['continent'].map(d)
visa_df

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)


d={}
for j in cat_cols[1:]:
    labels=visa_df[j].unique()
    for i in range(len(labels)):
        d[labels]
    
cat_cols=visa_df.select_dtypes(include='object').columns
cat_cols

# %% [markdown]
# $label$ $encoder$
#
# -lebel encoder is package available in sklearn
#
# -sickit learn heart of ML
#
# -read the data
#
# -save the package
#
# -apply fit transform

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the package
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)

# %%
from sklearn.preprocessing import LabelEncoder  # the the package
le= LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='education_of_employee',data=visa_df)
#sns.countplot(data=visa_df,x='has_job_experience',order=l)
plt.xlabel('year_of_estab')
plt.ylabel('no_of_employees')
plt.title("bar chart")
plt.savefig('continent_bar.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(y='no_of_employees',x='yr_of_estab',
       data=visa_df)
plt.xlabel('year_of_estab')
plt.ylabel('no_of_employees')
plt.title("bar chart")
plt.savefig('continent_bar.jpg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 plt.bar(y='no_of_employees',x='yr_of_estab',
#       3        data=visa_df)
#       4 plt.xlabel('year_of_estab')
#       5 plt.ylabel('no_of_employees')
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['has_job_experience'].value_counts().keys()
# Out:
# Index(['Y', 'N'], dtype='object', name='has_job_experience')

# %%
plt.figure(figsize=(10,6))
l=visa_df['has_job_experience'].value_counts().keys()
sns.countplot(data=visa_df,x='has_job_experience',order=l)
plt.xlabel('has_job_experience')
plt.ylabel('count')
plt.title("bar chart")
plt.savefig('has_job_experience.jpg')
plt.show()

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
visa_df['has_job_experience'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
d={'Y':1,'N':0}
visa_df['has_job_experience']=visa_df['has_job_experience'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d={}
labels=visa_df['has_job_experience'].unique()
for i in range(len(labels)):
    d[labels[i]]=i
visa_df['has_job_experience']=visa_df['has_job_experience'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_cols=visa_df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder  # the the package
le= LabelEncoder()

for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
le.inverse_transform(visa_df['continent'][:5])
# Out:
# array([1, 1, 1, 1, 0], dtype=int64)

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])

# %% [markdown]
# $np.where$

# %% [markdown]
# -np.where required 3 arguements
#
# -condition
#
# -True
#
# -False
#
# -it is applicable only for binary labels
#
# -case status has only two labels Certified and Denied
#
# -if case status==Certified replcetht as 0,otherwise 1

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $one heart encoder$

# %%
--one heart encoder name says at a time one will on and other will off

--for example case case status has two labels
  
    -Certified
    
    -denied
    
-when you apply one hot encoding on case status , it creates two more extra column

   - case- status_Certified
    
    -case_status_Denied
    
|case_status|case

# %% [markdown]
# # Advantages
# -when you develop ML model it is very important the columns should be independent each other
#
# -so here case status creating two extra column
#
# -which are independent each other ,which means  the row values at a time only one column has 1

# %% [markdown]
# # Disadvantages
#
# -The disadvantages is if a column has 100 unique labels,100 new columns will be
#
# -The data will become sparse ,which means huge
#
# -columns are more means, Dimensions are more
#
# -The processing time is more
#
# -The memory time consumption is more
#
# -Curse of Dimensionality`

# %%
#read the data
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)
pd.get_dummies(visa_df,columns=['case_status'])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)
pd.get_dummies(visa_df,columns=['education_of_employee','case_status'],dtype='int')
# Out:
#          case_id continent has_job_experience requires_job_training  \
# 0         EZYV01      Asia                  N                     N
# 1         EZYV02      Asia                  Y                     N
# 2         EZYV03      Asia                  N                     Y
# 3         EZYV04      Asia                  N                     N
# 4         EZYV05    Africa                  Y                     N
# ...          ...       ...                ...                   ...
# 25475  EZYV25476      Asia                  Y                     Y
# 25476  EZYV25477      Asia                  Y                     N
# 25477  EZYV25478      Asia                  Y                     N
# 25478  EZYV25479      Asia                  Y                     Y
# 25479  EZYV25480      Asia                  Y                     N
#
#        no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0                14513         2007                 West         592.2029
# ...

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)
pd.get_dummies(visa_df,columns=['education_of_employee','case_status'],dtype='int')

# %%
path=r"C:\Users\tanma\DATASCIENCE\string & list\Visadataset.xlsx"
visa_df=pd.read_excel(path)
#make sure drop the id column
visa_df.drop('case_id',axis=1,inplace=True)
pd.get_dummies(visa_df,dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  continent_Africa  \
# 0                14513         2007         592.2029                 0
# 1                 2412         2002       83425.6500                 0
# 2                44444         2008      122996.8600                 0
# 3                   98         1897       83434.0300                 0
# 4                 1082         2005      149907.3900                 1
# ...                ...          ...              ...               ...
# 25475             2601         2008       77092.5700                 0
# 25476             3274         2006      279174.7900                 0
# 25477             1121         1910      146298.8500                 0
# 25478             1918         1887       86154.7700                 0
# 25479             3195         1960       70876.9100                 0
#
#        continent_Asia  continent_Europe  continent_North America  \
# ...
